# %% [markdown]
# # Data Scraping from IMDB

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
from textblob import TextBlob
from requests import get
from time import sleep
from random import randint
from warnings import warn
import matplotlib.pyplot as plt

# %%
pages = np.arange(1, 20, 50) 
headers = {'Accept-Language': 'en-US,en;q=0.8'} # If this is not specified, the default language is Mandarin

# %% [markdown]
# # Initialize empty lists to store the variables scraped

# %%
titles = []
years = []
ratings = []
genres = []
runtimes = []
imdb_ratings = []
imdb_ratings_standardized = []
metascores = []
votes = []

# %%
for page in pages:
    
    #get request
    response = get("https://www.imdb.com/search/title?genres=sci-fi&" 
                   + "start=" 
                   + str(page) 
                   + "&explore=title_type,genres&ref_=adv_prv")
    
    sleep(randint(8,15))
     
    #throw warning for status codes that are not 200
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(requests, response.status_code))

    #parse the content of current iteration of request
    page_html = BeautifulSoup(response.text, 'html.parser')
        
    movie_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')
    
    #extract the 50 movies for that page
    for container in movie_containers:

        #conditional for all with metascore
        if container.find('div', class_ = 'ratings-metascore') is not None:

            #title
            title = container.h3.a.text
            titles.append(title)

            #year released
            year = container.h3.find('span', class_= 'lister-item-year text-muted unbold').text
            years.append(year)

            #rating
            rating = container.p.find('span', class_= 'certificate')
            ratings.append(rating)

            #genre
            genre = container.p.find('span', class_ = 'genre').text
            genres.append(genre)

            #runtime
            time = container.p.find('span', class_ = 'runtime').text
            runtimes.append(time)

            #IMDB ratings
            imdb = float(container.strong.text)
            imdb_ratings.append(imdb)

            #Metascore
            m_score = container.find('span', class_ = 'metascore').text
            metascores.append(int(m_score))

            #Number of votes
            vote = container.find('span', attrs = {'name':'nv'})['data-value']
            votes.append(int(vote))

# %%
sci_fi_df = pd.DataFrame({'movie': titles,
                      'year': years,
                      'rating': ratings,
                      'genre': genres,
                      'runtime_min': runtimes,
                      'imdb': imdb_ratings,
                      'metascore': metascores,
                      'votes': votes}
                      )

sci_fi_df.loc[:, 'year'] = sci_fi_df['year'].str[-5:-1] # two more data transformations after scraping
# Drop 'ovie' bug
# Make year an int
sci_fi_df['n_imdb'] = sci_fi_df['imdb'] * 10
final_df = sci_fi_df.loc[sci_fi_df['year'] != 'ovie'] # One small issue with the scrape on these two movies so just dropping those ones.
final_df.loc[:, 'year'] = pd.to_numeric(final_df['year'])

# %%
sci_fi_df
# Out:
#                                  movie  year   rating  \
# 0            Avatar: O Caminho da Água  2022     [14]
# 1    Tudo em Todo Lugar ao Mesmo Tempo  2022     [14]
# 2                                M3gan  2022     [14]
# 3                        Infinity Pool  2023      [R]
# 4                               Jung_E  2023     [16]
# 5                               Avatar  2009     [12]
# 6                The Wandering Earth 2  2023     None
# 7   Pantera Negra: Wakanda para Sempre  2022     [12]
# 8                               Vesper  2022     None
# 9                           Adão Negro  2022     [14]
# 10              Jurassic World Domínio  2022     [12]
# 11                      Não! Não Olhe!  2022     [14]
# 12                        Interestelar  2014     [10]
# 13                                Duna  2021     [14]
# 14                 Thor: Amor e Trovão  2022     [14]
# 15                      Mundo Estranho  2022  [Livre]
# 16                            A Origem  2010     [14]
# 17   Homem-Aranha: Sem Volta para Casa  2021     [12]
#
#                                          genre runtime_min  imdb  metascore  \
# 0     \nAction, Adventure, Fantasy                 192 min   7.8         67
# 1      \nAction, Adventure, Comedy                 139 min   8.0         81
# 2       \nHorror, Sci-Fi, Thriller                 102 min   6.4         72
# 3         \nCrime, Horror, Mystery                 117 min   6.9         72
# 4       \nAction, Adventure, Drama                  98 min   5.4         53
# 5     \nAction, Adventure, Fantasy                 162 min   7.9         83
# 6       \nAction, Adventure, Drama                 173 min   8.0         56
# 7       \nAction, Adventure, Drama                 161 min   7.1         67
# 8       \nAdventure, Drama, Sci-Fi                 114 min   5.9         70
# 9     \nAction, Adventure, Fantasy                 125 min   6.4         41
# 10     \nAction, Adventure, Sci-Fi                 147 min   5.6         38
# 11       \nHorror, Mystery, Sci-Fi                 130 min   6.9         77
# 12      \nAdventure, Drama, Sci-Fi                 169 min   8.6         74
# 13      \nAction, Adventure, Drama                 155 min   8.0         74
# 14     \nAction, Adventure, Comedy                 118 min   6.3         57
# 15  \nAnimation, Action, Adventure                 102 min   5.6         65
# 16     \nAction, Adventure, Sci-Fi                 148 min   8.8         74
# 17    \nAction, Adventure, Fantasy                 148 min   8.2         71
#
#       votes  n_imdb
# 0    275274    78.0
# 1    311194    80.0
# 2     47788    64.0
# 3      2764    69.0
# 4      6142    54.0
# 5   1315886    79.0
# 6      5233    80.0
# 7    152847    71.0
# 8     14504    59.0
# 9    217010    64.0
# 10   168229    56.0
# 11   196143    69.0
# 12  1851337    86.0
# 13   645496    80.0
# 14   340523    63.0
# 15    32949    56.0
# 16  2367898    88.0
# 17   766146    82.0

# %% [markdown]
# # Reviews

# %%
page = requests.get("https://www.imdb.com/title/tt1630029/reviews/?ref_=tt_ql_urv")
soup = BeautifulSoup(page.content, "html.parser")
rev = soup.findAll('div', class_='text show-more__control')
movies = []
for movie in rev:
    movies.append(movie.text)
df_subset = pd.DataFrame()
df_subset['Avatar: O Caminho da Água']=movies

# %%
df_subset
# Out:
#                             Avatar: O Caminho da Água
# 0   The strong suit of the first Avatar movie was ...
# 1   This sequel has a design and look that matches...
# 2   It's a James Cameron film, so it's impressive....
# 3   So, the dumbest thing they could have possibly...
# 4   James Cameron brings the biggest disappointmen...
# 5   It's hard to believe the sequel to Avatar has ...
# 6   Technically gorgeous, but the story is similar...
# 7   Without question, this has the best CG works I...
# 8   Massive advertising will make sure (just like ...
# 9   He did it again. And I don't even really under...
# 10  If you loved the first movie, you are likely t...
# 11  I should preface this by saying I'm a huge Jam...
# 12  Okay. I'm just gunna write from my heart here ...
# 13  The visual effects were great on the actual Na...
# 14  This film is visually stunning. It simply has ...
# 15  The movie while not fantastic storywise was ve...
# 16  One truly leaves this movie wondering, did the...
# 17  There is a reason Aristotle placed "spectacle"...
# 18  I saw the first one which was fantastic. I was...
# 19  Fake crying, fake smiles, unnecessary moaning ...
# 20  James Cameron has sadly not made a classic, bu...
# 21  First off, there is no such thing as a perfect...
# 22  James Cameron gives James Bond's Thunderball c...
# 23  I liked it, but it wasnt worth waiting 13 year...
# 24  The visuals are breathtaking. This is the type...

# %% [markdown]
# # Sentiments

# %%
df = pd.DataFrame()

# %%
df['Reviews of people']=movies

# %%
list=[]
for i in range(len(movies)):
    text=TextBlob(movies[i])
    x=text.sentiment.polarity # x between -1 and 1
    list.append(round(x,2))

# %%
sent=[]
j=[]
for j in list:
    if j>0:
        x="positive"
    elif j==0:
        x="neutre"
    else :
        x="negative"
    sent.append(x)

# %%
df['sentiment']=sent

# %%
df
# Out:
#                                     Reviews of people sentiment
# 0   The strong suit of the first Avatar movie was ...  positive
# 1   This sequel has a design and look that matches...  positive
# 2   It's a James Cameron film, so it's impressive....  positive
# 3   So, the dumbest thing they could have possibly...  positive
# 4   James Cameron brings the biggest disappointmen...  positive
# 5   It's hard to believe the sequel to Avatar has ...  positive
# 6   Technically gorgeous, but the story is similar...  positive
# 7   Without question, this has the best CG works I...  positive
# 8   Massive advertising will make sure (just like ...  positive
# 9   He did it again. And I don't even really under...  positive
# 10  If you loved the first movie, you are likely t...  positive
# 11  I should preface this by saying I'm a huge Jam...  positive
# 12  Okay. I'm just gunna write from my heart here ...  positive
# 13  The visual effects were great on the actual Na...  positive
# 14  This film is visually stunning. It simply has ...  positive
# 15  The movie while not fantastic storywise was ve...  positive
# 16  One truly leaves this movie wondering, did the...  positive
# 17  There is a reason Aristotle placed "spectacle"...  negative
# 18  I saw the first one which was fantastic. I was...  positive
# 19  Fake crying, fake smiles, unnecessary moaning ...  negative
# 20  James Cameron has sadly not made a classic, bu...  positive
# 21  First off, there is no such thing as a perfect...  positive
# 22  James Cameron gives James Bond's Thunderball c...  positive
# 23  I liked it, but it wasnt worth waiting 13 year...  positive
# 24  The visuals are breathtaking. This is the type...  positive
